# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df = pd.read_csv("/content/emails.csv")

X = df["text"].astype(str).values
y = df["spam"].values   # 0 or 1 labels

# %%
vectorizer = TfidfVectorizer()
X_vectors = vectorizer.fit_transform(X)

# %%
# Split data (150 train, 50 test)
X_train, X_test, y_train, y_test = train_test_split(
    X_vectors, y, test_size=50, train_size=150, random_state=42, stratify=y
)

# %%
# Train model (LinearRegression)
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
sample_emails = X_test   # all 50 test emails

# %%
outputs = model.predict(sample_emails)

print("Categories: ['not spam', 'spam']")

for i, out in enumerate(outputs):
    prediction = "Spam" if out > 0.5 else "Not Spam"
    print(f"Email {i+1}: Output = {out:.4f} -> Prediction: {prediction}")

print("\n" + "="*60 + "\n")
# Out:
# Categories: ['not spam', 'spam']
# Email 1: Output = 0.4296 -> Prediction: Not Spam
# Email 2: Output = 0.5244 -> Prediction: Spam
# Email 3: Output = 0.3081 -> Prediction: Not Spam
# Email 4: Output = 0.4619 -> Prediction: Not Spam
# Email 5: Output = 0.9636 -> Prediction: Spam
# Email 6: Output = 0.2375 -> Prediction: Not Spam
# Email 7: Output = 0.2444 -> Prediction: Not Spam
# Email 8: Output = 0.0437 -> Prediction: Not Spam
# Email 9: Output = 0.1528 -> Prediction: Not Spam
# Email 10: Output = 0.5583 -> Prediction: Spam
# Email 11: Output = 0.2519 -> Prediction: Not Spam
# Email 12: Output = 0.2840 -> Prediction: Not Spam
# Email 13: Output = 0.1053 -> Prediction: Not Spam
# Email 14: Output = 0.0344 -> Prediction: Not Spam
# Email 15: Output = 0.1132 -> Prediction: Not Spam
# Email 16: Output = 0.5418 -> Prediction: Spam
# Email 17: Output = 0.3530 -> Prediction: Not Spam
# Email 18: Output = 0.2247 -> Prediction: Not Spam
# Email 19: Output = 0.2965 -> Prediction: Not Spam
# Email 20: Output = 0.1872 -> Prediction: Not Spam
# Email 21: Output = 0.1654 -> Prediction: Not Spam
# Email 22: Output = 0.7135 -> Prediction: Spam
# Email 23: Output = 0.0800 -> Prediction: Not Spam
# Email 24: Output = 0.1034 -> Prediction: Not Spam
# Email 25: Output = 0.2549 -> Prediction: Not Spam
# Email 26: Output = 0.2691 -> Prediction: Not Spam
# Email 27: Output = 0.6075 -> Prediction: Spam
# Email 28: Output = 0.4888 -> Prediction: Not Spam
# Email 29: Output = 0.0363 -> Prediction: Not Spam
# Email 30: Output = 0.3019 -> Prediction: Not Spam
# Email 31: Output = 0.3846 -> Prediction: Not Spam
# Email 32: Output = 0.2715 -> Prediction: Not Spam
# Email 33: Output = 0.2373 -> Prediction: Not Spam
# Email 34: Output = 0.1692 -> Prediction: Not Spam
# Email 35: Output = 0.2181 -> Prediction: Not Spam
# Email 36: Output = 0.2881 -> Prediction: Not Spam
# Email 37: Output = 0.1650 -> Prediction: Not Spam
# Email 38: Output = 0.1093 -> Prediction: Not Spam
# Email 39: Output = -0.0201 -> Prediction: Not Spam
# Email 40: Output = 0.0634 -> Prediction: Not Spam
# Email 41: Output = 0.1609 -> Prediction: Not Spam
# Email 42: Output = 0.0628 -> Prediction: Not Spam
# Email 43: Output = -0.0754 -> Prediction: Not Spam
# Email 44: Output = 0.1098 -> Prediction: Not Spam
# Email 45: Output = 0.0752 -> Prediction: Not Spam
# Email 46: Output = 0.5670 -> Prediction: Spam
# Email 47: Output = 0.1074 -> Prediction: Not Spam
# Email 48: Output = 0.4866 -> Prediction: Not Spam
# Email 49: Output = -0.0143 -> Prediction: Not Spam
# Email 50: Output = 0.3846 -> Prediction: Not Spam
#
# ============================================================
